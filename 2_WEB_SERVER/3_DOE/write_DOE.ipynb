# %%
import pandas as pd
import numpy as np
import glob
import os 
import pingouin as pg
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
def read_files(path_dir):
    res_df      = pd.DataFrame(None, columns=['ResponseTime', 'Request Rate', 'page size', 'Request Rate * page size'])     
    for elem in glob.glob(path_dir + "*.csv"):
        print('---AVVIO LETTURA: ', elem)
        tempDF = pd.read_csv(elem)
        tempDF = tempDF[tempDF.responseMessage == 'OK']
        ResponseTime = tempDF['elapsed'].mean()
        
        path_tail = os.path.split(elem)
        name = path_tail[1].split('_')[1].split('.')[0]
        label = path_tail[1].split('_')[0]
        
        if 'CatturaL' in label:
            label = 'L'
        if 'CatturaMH' in label:
            label = 'MH'
        if 'CatturaML' in label:
            label = 'ML'
        if 'CatturaS' in label:
            label = 'S'
        
        if name == '9k':
            name = 9000
        else:
            name = 3000
        res_df.loc[len(res_df.index)] = [ResponseTime, name, label, ]

    return res_df

def qq_plot(series_name, df):
        plt.title(series_name)
        ax = pg.qqplot(df[series_name], dist='norm', confidence=.95)
        test = stats.shapiro(df[series_name])
        print(test)
        plt.show()

def variance(series_name, df):
    plt.title(series_name)
    plt.scatter(df[series_name], df['ResponseTime'])
    plt.xlabel(series_name)
    plt.ylabel('ResponseTime')

# %%
path_dir = 'C:/Users/stefa/Desktop/Impianti/impianti_pratica/DOE/OsservazioniDOE/'
df= read_files(path_dir)
# Out:
# ---AVVIO LETTURA:  C:/Users/stefa/Desktop/Impianti/impianti_pratica/DOE/OsservazioniDOE\CatturaL01_3k.csv
# ---AVVIO LETTURA:  C:/Users/stefa/Desktop/Impianti/impianti_pratica/DOE/OsservazioniDOE\CatturaL02_3k.csv
# ---AVVIO LETTURA:  C:/Users/stefa/Desktop/Impianti/impianti_pratica/DOE/OsservazioniDOE\CatturaL03_3k.csv
# ---AVVIO LETTURA:  C:/Users/stefa/Desktop/Impianti/impianti_pratica/DOE/OsservazioniDOE\CatturaL04_3k.csv
# ---AVVIO LETTURA:  C:/Users/stefa/Desktop/Impianti/impianti_pratica/DOE/OsservazioniDOE\CatturaL05_3k.csv
# ---AVVIO LETTURA:  C:/Users/stefa/Desktop/Impianti/impianti_pratica/DOE/OsservazioniDOE\CatturaL06_9k.csv
# ---AVVIO LETTURA:  C:/Users/stefa/Desktop/Impianti/impianti_pratica/DOE/OsservazioniDOE\CatturaL07_9k.csv
# ---AVVIO LETTURA:  C:/Users/stefa/Desktop/Impianti/impianti_pratica/DOE/OsservazioniDOE\CatturaL08_9k.csv
# ---AVVIO LETTURA:  C:/Users/stefa/Desktop/Impianti/impianti_pratica/DOE/OsservazioniDOE\CatturaL09_9k.csv
# ---AVVIO LETTURA:  C:/Users/stefa/Desktop/Impianti/impianti_pratica/DOE/OsservazioniDOE\CatturaL10_9k.csv
# ---AVVIO LETTURA:  C:/Users/stefa/Desktop/Impianti/impianti_pratica/DOE/OsservazioniDOE\CatturaMH01_3k.csv
# ---AVVIO LETTURA:  C:/Users/stefa/Desktop/Impianti/impianti_pratica/DOE/OsservazioniDOE\CatturaMH02_3k.csv
# ---AVVIO LETTURA:  C:/Users/stefa/Desktop/Impianti/impianti_pratica/DOE/OsservazioniDOE\CatturaMH03_3k.csv
# ---AVVIO LETTURA:  C:/Users/stefa/Desktop/Impianti/impianti_pratica/DOE/OsservazioniDOE\CatturaMH04_3k.csv
# ---AVVIO LETTURA:  C:/Users/stefa/Desktop/Impianti/impianti_pratica/DOE/OsservazioniDOE\CatturaMH05_3k.csv
# ---AVVIO LETTURA:  C:/Users/stefa/Desktop/Impianti/impianti_pratica/DOE/OsservazioniDOE\CatturaMH06_9k.csv
# ---AVVIO LETTURA:  C:/Users/stefa/Desktop/Impianti/impianti_pratica/DOE/OsservazioniDOE\CatturaMH07_9k.csv
# ---AVVIO LETTURA:  C:/Users/stefa/Desktop/Impianti/impianti_pratica/DOE/OsservazioniDOE\CatturaMH08_9k.csv
# ---AVVIO LETTURA:  C:/Users/stefa/Desktop/Impianti/impianti_pratica/DOE/OsservazioniDOE\CatturaMH09_9k.csv
# ---AVVIO LETTURA:  C:/Users/stefa/Desktop/Impianti/impianti_pratica/DOE/OsservazioniDOE\CatturaMH10_9k.csv
# ---AVVIO LETTURA:  C:/Users/stefa/Desktop/Impianti/impianti_pratica/DOE/OsservazioniDOE\CatturaML01_3k.csv
# ---AVVIO LETTURA:  C:/Users/stefa/Desktop/Impianti/impianti_pratica/DOE/OsservazioniDOE\CatturaML02_3k.csv
# ---AVVIO LETTURA:  C:/Users/stefa/Desktop/Impianti/impianti_pratica/DOE/OsservazioniDOE\CatturaML03_3k.csv
# ---AVVIO LETTURA:  C:/Users/stefa/Desktop/Impianti/impianti_pratica/DOE/OsservazioniDOE\CatturaML04_3k.csv
# ---AVVIO LETTURA:  C:/Users/stefa/Desktop/Impianti/impianti_pratica/DOE/OsservazioniDOE\CatturaML05_3k.csv
# ---AVVIO LETTURA:  C:/Users/stefa/Desktop/Impianti/impianti_pratica/DOE/OsservazioniDOE\CatturaML06_9k.csv
# ---AVVIO LETTURA:  C:/Users/stefa/Desktop/Impianti/impianti_pratica/DOE/OsservazioniDOE\CatturaML07_9k.csv
# ---AVVIO LETTURA:  C:/Users/stefa/Desktop/Impianti/impianti_pratica/DOE/OsservazioniDOE\CatturaML08_9k.csv
# ---AVVIO LETTURA:  C:/Users/stefa/Desktop/Impianti/impianti_pratica/DOE/OsservazioniDOE\CatturaML09_9k.csv
# ---AVVIO LETTURA:  C:/Users/stefa/Desktop/Impianti/impianti_pratica/DOE/OsservazioniDOE\CatturaML10_9k.csv
# ---AVVIO LETTURA:  C:/Users/stefa/Desktop/Impianti/impianti_pratica/DOE/OsservazioniDOE\CatturaS01_3k.csv
# ---AVVIO LETTURA:  C:/Users/stefa/Desktop/Impianti/impianti_pratica/DOE/OsservazioniDOE\CatturaS02_3k.csv
# ---AVVIO LETTURA:  C:/Users/stefa/Desktop/Impianti/impianti_pratica/DOE/OsservazioniDOE\CatturaS03_3k.csv
# ---AVVIO LETTURA:  C:/Users/stefa/Desktop/Impianti/impianti_pratica/DOE/OsservazioniDOE\CatturaS04_3k.csv
# ---AVVIO LETTURA:  C:/Users/stefa/Desktop/Impianti/impianti_pratica/DOE/OsservazioniDOE\CatturaS05_3k.csv
# ---AVVIO LETTURA:  C:/Users/stefa/Desktop/Impianti/impianti_pratica/DOE/OsservazioniDOE\CatturaS06_9k.csv
# ---AVVIO LETTURA:  C:/Users/stefa/Desktop/Impianti/impianti_pratica/DOE/OsservazioniDOE\CatturaS07_9k.csv
# ---AVVIO LETTURA:  C:/Users/stefa/Desktop/Impianti/impianti_pratica/DOE/OsservazioniDOE\CatturaS08_9k.csv
# ---AVVIO LETTURA:  C:/Users/stefa/Desktop/Impianti/impianti_pratica/DOE/OsservazioniDOE\CatturaS09_9k.csv
# ---AVVIO LETTURA:  C:/Users/stefa/Desktop/Impianti/impianti_pratica/DOE/OsservazioniDOE\CatturaS10_9k.csv

# %%
df
# Out:
#     ResponseTime  Request Rate label          mean      Residuo
# 0   14593.052632          3000     L  18126.820698 -3533.768067
# 1    9137.421053          3000     L  18126.820698 -8989.399646
# 2   23471.500000          3000     L  18126.820698  5344.679302
# 3   22532.437500          3000     L  18126.820698  4405.616802
# 4   20899.692308          3000     L  18126.820698  2772.871609
# 5   22249.875000          9000     L  16679.286915  5570.588085
# 6   17994.052632          9000     L  16679.286915  1314.765716
# 7   20257.562500          9000     L  16679.286915  3578.275585
# 8   10020.944444          9000     L  16679.286915 -6658.342471
# 9   12874.000000          9000     L  16679.286915 -3805.286915
# 10     40.183024          3000    MH     35.079318     5.103706
# 11     68.826209          3000    MH     35.079318    33.746891
# 12      9.770736          3000    MH     35.079318   -25.308582
# 13     24.024023          3000    MH     35.079318   -11.055296
# 14     32.592599          3000    MH     35.079318    -2.486719
# 15     71.051194          9000    MH     86.608301   -15.557108
# 16     83.746285          9000    MH     86.608301    -2.862017
# 17     55.468167          9000    MH     86.608301   -31.140134
# 18    133.627999          9000    MH     86.608301    47.019697
# 19     89.147863          9000    MH     86.608301     2.539561
# 20      6.689009          3000    ML      7.761881    -1.072872
# 21      6.686918          3000    ML      7.761881    -1.074962
# 22      9.128818          3000    ML      7.761881     1.366937
# 23      9.044819          3000    ML      7.761881     1.282938
# 24      7.259840          3000    ML      7.761881    -0.502040
# 25      8.523727          9000    ML     14.976017    -6.452290
# 26     11.921515          9000    ML     14.976017    -3.054502
# 27     19.987562          9000    ML     14.976017     5.011545
# 28     18.070194          9000    ML     14.976017     3.094177
# 29     16.377087          9000    ML     14.976017     1.401070
# 30      2.464581          3000     S      2.552974    -0.088393
# 31      2.433382          3000     S      2.552974    -0.119592
# 32      2.677372          3000     S      2.552974     0.124398
# 33      2.565775          3000     S      2.552974     0.012801
# 34      2.623760          3000     S      2.552974     0.070786
# 35      2.100569          9000     S      1.936054     0.164515
# 36      1.747586          9000     S      1.936054    -0.188468
# 37      1.829713          9000     S      1.936054    -0.106341
# 38      2.000667          9000     S      1.936054     0.064613
# 39      2.001735          9000     S      1.936054     0.065681

# %%
qq_plot('Residuo', df)
# Out:
# ShapiroResult(statistic=0.684859037399292, pvalue=5.5432224144169595e-08)

# %%
#df.to_csv('DOE.csv', sep=',')

# %%
import glob
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import pingouin as pg
from random import sample 


path_dir2_1 = 'C:/Users/stefa/Desktop/Impianti/impianti_pratica/Nbody/Osservazioni_vito/1/'
path_dir3_1 = 'C:/Users/stefa/Desktop/Impianti/impianti_pratica/Nbody/Osservazioni_paolo/1/'

path_dir1_2b = 'C:/Users/stefa/Desktop/Impianti/impianti_pratica/Nbody/Osservazioni_mie - 1/2/'
path_dir1_2a = 'C:/Users/stefa/Desktop/Impianti/impianti_pratica/Nbody/Osservazioni_mie - 2/2/'

path_dir2_2 = 'C:/Users/stefa/Desktop/Impianti/impianti_pratica/Nbody/Osservazioni_vito/2/'
path_dir3_2 = 'C:/Users/stefa/Desktop/Impianti/impianti_pratica/Nbody/Osservazioni_paolo/2/'

path_dir1_3 = 'C:/Users/stefa/Desktop/Impianti/impianti_pratica/Nbody/Osservazioni_mie - 2/3/'
path_dir2_3 = 'C:/Users/stefa/Desktop/Impianti/impianti_pratica/Nbody/Osservazioni_vito/3/'
path_dir3_3 = 'C:/Users/stefa/Desktop/Impianti/impianti_pratica/Nbody/Osservazioni_paolo/3/'

# %%
def read_files(path_dir):
    print('---AVVIO LETTURA---')
    for elem in glob.glob(path_dir + "*.txt"):
        row_elem = []
        for row in open(elem, "r"):
            val = float(row.split(' ')[1])
            row_elem.append(val)
        yield row_elem

def cov_files(path_dir):
    arr = []
    for elem in read_files(path_dir):
        arr.append(np.std(elem)/np.mean(elem))
    return arr
        
def mean_files(path_dir):
    arr = []
    for elem in read_files(path_dir):
        arr.append(np.mean(elem))
    return arr

def subs_arr(arr1, arr2):
    res = []
    for elem1, elem2 in zip(arr1, arr2):
        res.append(elem1-elem2)
    return res

def dim_camp(path_dir):
    #95% con  r% 15
    arr = []
    for elem in read_files(path_dir):  
        r = 15
        arr.append(np.power(196*np.std(elem)/(r*np.mean(elem)), 2))
    return arr

def qq_plot(data):
    for elem in data:
        print(len(elem))
        ax = pg.qqplot(elem, dist='norm', confidence=.95)
        test = stats.normaltest(elem)
        print(test)
        plt.show()   

def plot_confidence_interval(x, values, z=1.96, color='#2187bb', horizontal_line_width=0.25):
    mean = np.mean(values)
    stdev = np.std(values)
    confidence_interval = z * stdev / np.sqrt(len(values))

    left = x - horizontal_line_width / 2
    top = mean - confidence_interval
    right = x + horizontal_line_width / 2
    bottom = mean + confidence_interval
    plt.plot([x, x], [top, bottom], color=color)
    plt.plot([left, right], [top, top], color=color)
    plt.plot([left, right], [bottom, bottom], color=color)
    plt.plot(x, mean, 'o', color='#f44336')

    return mean, confidence_interval

def read_file(path):
    data = []
    data.append(mean_files(path + '1/'))
    data.append(mean_files(path + '2/'))
    data.append(mean_files(path + '3/'))
    return data

# %% [markdown]
# <img src="stefano_vs_vito.png" style="height:300px"/>

# %%
test = 'C:/Users/stefa/Desktop/Impianti/impianti_pratica/Nbody/Osservazioni_vito_3/'
print(cov_files(test+'1/'))
# Out:
# ---AVVIO LETTURA---
# [0.33301825937529067, 0.00018756968915878335, 0.0012488372539050654, 0.00010002079715900727, 0.00011013564512013079, 0.3462343118114847, 0.00012437220947192029, 0.001956415204354446, 0.00033741984615435366, 0.3462352546988277, 0.00048139406834225097, 0.0002894763386806054, 0.0004183904048225342, 0.00012643401739658686, 0.34642968597862794, 0.00021585041956902743, 0.34671485789995543, 0.00015165564019347513, 9.48303317504036e-05, 0.0002191107525081034, 3.431496905633276e-05, 0.33323449905206853, 0.34638712297867424, 0.34645332316120514, 0.00029581871744442005, 0.0012069916551359103, 0.00022852451120830032, 0.0010290751879430883, 0.0003440744912139888, 0.0005036397915354664, 0.00017908849358316337, 0.34633152897600533, 0.00016808612390580455, 0.33332054186817056, 0.00011741980592244138, 0.00021024935930669242, 0.0015127788923433188, 0.00017676911331980668, 0.00019985212474844493, 0.000273531632459764]

# %%
mie_path_1 = 'C:/Users/stefa/Desktop/Impianti/impianti_pratica/Nbody/Osservazioni_mie_1/'
mie_path_2 = 'C:/Users/stefa/Desktop/Impianti/impianti_pratica/Nbody/Osservazioni_mie_2/'
mie_path_3 = 'C:/Users/stefa/Desktop/Impianti/impianti_pratica/Nbody/Osservazioni_mie_3/'

vito_path_1 = 'C:/Users/stefa/Desktop/Impianti/impianti_pratica/Nbody/Osservazioni_vito_1/'
vito_path_2 = 'C:/Users/stefa/Desktop/Impianti/impianti_pratica/Nbody/Osservazioni_vito_2/'
vito_path_3 = 'C:/Users/stefa/Desktop/Impianti/impianti_pratica/Nbody/Osservazioni_vito_3/'

paolo_path  = 'C:/Users/stefa/Desktop/Impianti/impianti_pratica/Nbody/Osservazioni_paolo/'

data_stefano_1 = read_file(mie_path_1)
data_stefano_2 = read_file(mie_path_2)
data_stefano_3 = read_file(mie_path_3)

data_vito_1 = read_file(vito_path_1)
data_vito_2 = read_file(vito_path_2)
data_vito_3 = read_file(vito_path_3)

data_paolo = read_file(paolo_path)
# Out:
# ---AVVIO LETTURA---
# ---AVVIO LETTURA---
# ---AVVIO LETTURA---
# ---AVVIO LETTURA---
# ---AVVIO LETTURA---
# ---AVVIO LETTURA---
# ---AVVIO LETTURA---
# ---AVVIO LETTURA---
# ---AVVIO LETTURA---
# ---AVVIO LETTURA---
# ---AVVIO LETTURA---
# ---AVVIO LETTURA---
# ---AVVIO LETTURA---
# ---AVVIO LETTURA---
# ---AVVIO LETTURA---
# ---AVVIO LETTURA---
# ---AVVIO LETTURA---
# ---AVVIO LETTURA---
# ---AVVIO LETTURA---
# ---AVVIO LETTURA---
# ---AVVIO LETTURA---

# %% [raw]
# print(data_vito_3[0])
# for arr in data_stefano_2:
#     for i, elem in enumerate(arr):
#         arr[i] = arr[i]/1000
# print(data_vito_3[0]

# %%
for elem in data_stefano_3:
    print(len(elem))
    ax = pg.qqplot(elem, dist='norm', confidence=.95)
    test = stats.normaltest(elem)
    print(test)
    plt.show()
# Out:
# 40
# NormaltestResult(statistic=1.633056709127631, pvalue=0.44196333423542966)
# 40
# NormaltestResult(statistic=6.782909590744772, pvalue=0.0336596733261383)
# 0
# C:\Users\stefa\anaconda3\lib\site-packages\scipy\stats\_continuous_distns.py:411: RuntimeWarning: Mean of empty slice.
#   loc = data.mean()
# C:\Users\stefa\anaconda3\lib\site-packages\numpy\core\_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\stefa\anaconda3\lib\site-packages\scipy\stats\_continuous_distns.py:416: RuntimeWarning: Mean of empty slice.
#   scale = np.sqrt(((data - loc)**2).mean())
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 3
#       1 for elem in data_stefano_3:
#       2     print(len(elem))
# ----> 3     ax = pg.qqplot(elem, dist='norm', confidence=.95)
# ...

# %%
ax = pg.qqplot(prova, dist='norm', confidence=.95)
test = stats.normaltest(prova)
print(test)
plt.show()
# Out:
# NormaltestResult(statistic=0.5405572507836307, pvalue=0.763166827054768)

# %%
plot_confidence_interval(2,data_paolo[0])
plot_confidence_interval(1,data_stefano_1[0])
plt.show()

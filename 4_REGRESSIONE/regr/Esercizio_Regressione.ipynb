# %% [markdown]
# Exp 1: Rilevare e stimare eventuali trend su ognuna delle tre variabili nmail, byte_rec e byte_sent.
#
# - Passo 1: Calcolare i residui di ogni variabile
#
# - Passo 2: Andiamo a studiare la normalità dei residui tramite JMP utilizzando il qq-plot. In questo modo sarà possibile capire se possiamo applicare un modello regressivo parametrico oppure non parametrico;
#
# ![exp1_normalità.png](data:image/png;base64,...)
#
# Notiamo come nessuna delle 3 distribuzioni sia normale.
#
# - Passo 3: A questo punto, per studiare eventuali trend per le tre variabili di risposta andiamo ad utilizzare un test non parametrico, il test di Mann-Kendall; questo test è un modello di regressione non parametrico che ci consente di stabilire se esiste o meno un trend nei dati.
# Andiamo a studiare i risultati dell'hypothesis test:
# 1. H0 = Non esiste un trend nei dati;
# 2. H1 = Esiste un trend nei dati.
#
# ![exp1_kendall.png](data:image/png;base64,...)
#
# Le righe che interessano a noi sono quelle con le nostre 3 Variable: nmail, byte_rec e byte_sent associate al Variable By: Observation.
# Quando il valore del p-value è alto siamo molto confidenti che l'ipotesi nulla
# non verrà rigettata, e che quindi non esiste un TREND nei dati.
# Riguardo nmail e byte_rec non esiste un TREND nei dati.
# Per quanto riguarda byte_sent abbiamo un p-value molto basso (viene indicato con il colore rosso su JMP). Ciò indica la presenza di un TREND. Con il codice sotto-riportato è possibile calcolare lo slope pari a: -9.667414291365773
#
#
# Exp 2: Rilevare e stimare eventuali trend su ognuna delle tre variabili nmail, byte_rec e byte_sent.
#
# - Passo 1: Calcolare i residui di ogni variabile
#
# - Passo 2: Andiamo a studiare la normalità dei residui tramite JMP utilizzando il qq-plot. In questo modo sarà possibile capire se possiamo applicare un modello regressivo parametrico oppure non parametrico;
#
# ![exp2_normalità.png](data:image/png;base64,...)
#
# Notiamo come nessuna delle 3 distribuzioni sia normale.
#
# - Passo 3: A questo punto, seguiamo gli stessi passaggi di prima tramite il test di Mann-Kendall;
# Andiamo a studiare i risultati dell'hypothesis test:
# 1. H0 = Non esiste un trend nei dati;
# 2. H1 = Esiste un trend nei dati.
#
# ![exp2_kendall.png](data:image/png;base64,...)
#
# Guardando esclusivamente alle variabili nmail, byte_rec e byte_sent nella stessa
# riga di observation nella colonna ”Variable by”, vediamo come tutti i p-value sianombassi, rigettando quindi l'ipotesi nulla.
# Lo slope  di nmail è pari a: -0.0005973715651135006.
# Lo slope di byte_rec è pari a : -48.29360967184802.
# Lo slope di byte_sent è pari a: -34.06305208650625.
#
#
# Oss1: Rilevare e stimare eventuali trend sulle 5 variabili utilizzando modelli regressivi lineari semplici, parametrici e/o non parametrici. Farlo per i tre dataset os1, os2 e os3. Confrontare i trend individuati nei tre dataset
#
# - Passo 1: Calcolare i residui di ogni variabile
#
# - Passo 2: Andiamo a studiare la normalità dei residui tramite JMP utilizzando il qq-plot. In questo modo sarà possibile capire se possiamo applicare un modello regressivo parametrico oppure non parametrico;
#
# ![oss1_normalità1.png](data:image/png;base64,...)
#
# ![oss1_normalità2.png](data:image/png;base64,...)
#
# Notiamo come nessuna delle 5 distribuzioni sia normale.
#
# - Passo 3: Test di Mann-Kendall;
#
# ![oss1_Kendall.png](data:image/png;base64,...)
#
# Dal test si nota come l'ipotesi nulla H0 venga rigettata per le variabili VmSize, VmData, LRSS e byteletti_IO, mentre non viene rigettato per byteletti_IO1.
#
# 1. slope VmSize = 0.03157224220623501
# 2. slope VmData = 0.03157224220623501
# 3. slope RSS = 0.004970760233918129
# 4. slope byte_letti_IO = 4.737578125
#
# Oss2: Rilevare e stimare eventuali trend sulle 5 variabili utilizzando modelli regressivi lineari semplici, parametrici e/o non parametrici. Farlo per i tre dataset os1, os2 e os3. Confrontare i trend individuati nei tre dataset
#
# - Passo 1: Calcolare i residui di ogni variabile
#
# - Passo 2: Andiamo a studiare la normalità dei residui tramite JMP utilizzando il qq-plot. In questo modo sarà possibile capire se possiamo applicare un modello regressivo parametrico oppure non parametrico;
#
# ![oss2_normalità1.png](data:image/png;base64,...)
#
# ![oss2_normalità2.png](data:image/png;base64,...)
#
# Notiamo come nessuna delle 5 distribuzioni sia normale.
#
# - Passo 3: Test di Mann-Kendall;
#
# ![oss2_Kendall.png](data:image/png;base64,...)
#
# Vediamo come quindi in questo caso tutti i p-value (che abbiano sempre nella
# colonna ”variable by” la scritta TIME) siano bassi, quindi viene rigettato H0 e
# quindi esiste un trend nein tutti i dati; a questo punto, andiamo a calcolare gli slope.
#
# 1. slope VmSize = 0.0019128745423298214
# 2. slope VmData = 0.0019128745423298214
# 3. slope RSS = 0.0006324666198172874
# 4. slope byte_letti_al_sec = 114.55350983796296
# 5. slope byte_scritti_al_sec = -0.48861262488646684
#
# Oss3: Rilevare e stimare eventuali trend sulle 5 variabili utilizzando modelli regressivi lineari semplici, parametrici e/o non parametrici. Farlo per i tre dataset os1, os2 e os3. Confrontare i trend individuati nei tre dataset
#
# - Passo 1: Calcolare i residui di ogni variabile
#
# - Passo 2: Andiamo a studiare la normalità dei residui tramite JMP utilizzando il qq-plot. In questo modo sarà possibile capire se possiamo applicare un modello regressivo parametrico oppure non parametrico;
#
# ![oss3_normalità1.png](data:image/png;base64,...)
#
# ![oss3_normalità2.png](data:image/png;base64,...)
#
# Notiamo come nessuna delle 5 distribuzioni sia normale.
#
# - Passo 3: Test di Mann-Kendall;
#
# ![oss3_Kendall.png](data:image/png;base64,...)
#
# Dal test si nota come l'ipotesi nulla H0 venga rigettata per le variabili VmSize, VmData, LRSS e byteletti_IO, mentre non viene rigettato per byte_scritti_al_sec.
#
# 1. slope VmSize = 0.021659324522760644
# 2. slope VmData = 0.021659324522760644
# 3. slope RSS = 0.0034579439252336447
# 4. slope byte_letti_al_sec = -1.891048815359477
#
#
# Confronto dei trend nei tre dataset
# In prima analisi, notiamo come il trend nei dati ”byte scritti al secondo” esista sono nel dataset os2. Per quanto riguarda le altre 4 variabili X, notiamo come VmSize, VmData e RSS abbiano lo stesso slope per tutti e tre i dataset (fermandoci alla seconda/terza cifra significativa), mentre differiscono di molto il trend nei dati ”byte letti al secondo”: in particolare,
# in os2 il valore dello slope è molto piu alto rispetto agli altri due dataset.
#
# VMres1: Supponendo di avere un limite massimo alla memoria heap di 1 GByte. Rilevare un eventuale trend di consumo dello heap nell'esperimento in figura. Se rilevato il trend, stimare il tempo in cui lo heap satura (failure prediction).
#
# - Passo 1: Calcolare i residui di ogni variabile
#
# - Passo 2: Andiamo a studiare la normalità dei residui tramite JMP utilizzando il qq-plot. In questo modo sarà possibile capire se possiamo applicare un modello regressivo parametrico oppure non parametrico;
#
# ![VMres1_normalità.png](data:image/png;base64,...)
#
# Notiamo come nessuna delle 5 distribuzioni sia normale.
#
# - Passo 3: Test di Mann-Kendall;
#
# ![VMres1_Kendall.png](data:image/png;base64,...)
#
# L'ipotesi nulla è rigettata; esiste quindi un trend nei dati. A questo punto,
# andiamo a calcolare lo slope; in questo caso, siccome vogliamo calcolare anche
# dopo quanto tempo l'heap è saturo e raggiunge 1 GB di memoria, andiamo a
# calcolare pure l'intercetta per avere la nostra retta:
#
# 1. slope = 0.6911224682945296;
# 2. intercept = 6562275.461669506;
#
# Otteniamo che l’heap verrà saturato dopo 1.439.764.818 secondi, cioè circa 45,6
# anni.
#
# VMres2: Supponendo di avere un limite massimo alla memoria heap di 1 GByte. Rilevare un eventuale trend di consumo dello heap nell'esperimento in figura. Se rilevato il trend, stimare il tempo in cui lo heap satura (failure prediction).
#
# - Passo 1: Calcolare i residui di ogni variabile
#
# - Passo 2: Andiamo a studiare la normalità dei residui tramite JMP utilizzando il qq-plot. In questo modo sarà possibile capire se possiamo applicare un modello regressivo parametrico oppure non parametrico;
#
# ![VMres2_normalità.png](data:image/png;base64,...)
#
# Notiamo come nessuna delle 5 distribuzioni sia normale.
#
# - Passo 3: Test di Mann-Kendall;
#
# ![VMres2_Kendall.png](data:image/png;base64,...)
#
# L'ipotesi nulla è rigettata; esiste quindi un trend nei dati. A questo punto,
# andiamo a calcolare lo slope e l'intercetta:
#
# 1. slope = 0.6709499304572171
# 2. intercept = 5780180.563324536
#
# L’heap sarà saturo dopo 1.483.910.179 secondi, cioè circa 47 anni (un anno in meno del dataset precedente).
#
# VMres3: Supponendo di avere un limite massimo alla memoria heap di 1 GByte. Rilevare un eventuale trend di consumo dello heap nell’esperimento in figura. Se rilevato il trend, stimare il tempo in cui lo heap satura (failure prediction).
#
# - Passo 1: Calcolare i residui di ogni variabile
#
# - Passo 2: Andiamo a studiare la normalità dei residui tramite JMP utilizzando il qq-plot. In questo modo sarà possibile capire se possiamo applicare un modello regressivo parametrico oppure non parametrico;
#
# ![VMres3_normalità.png](data:image/png;base64,...)
#
# Notiamo come nessuna delle 5 distribuzioni sia normale.
#
# - Passo 3: Test di Mann-Kendall;
#
# ![VMres3_Kendall.png](data:image/png;base64,...)
#
# L'ipotesi nulla è rigettata; esiste quindi un trend nei dati. A questo punto,
# andiamo a calcolare lo slope e l'intercetta:
#
# 1. slope = 2.9030932760062105
# 2. intercept = 6041585.556431387
#
# L’heap si saturerà dopo 342744281 secondi, cioè circa 10 anni; Il motivo per cui la memoria saturerà molto prima delle altre è dovuto al valore dello slope più elevato (pendenza maggiore)

# %%
import pandas as pd
import sys
import numpy as np
import csv
import matplotlib.pyplot as plt
from scipy.stats.mstats import theilslopes
from scipy import stats
import os
Oss_path="/content/Regressione"

# %%
class FileCsv:
    def __init__(self):
        self.percorsi_file = []
        self.slope=[]
        self.intecept=[]
        self.Y11value=["byte sent"]
        self.Y12value=["byte sent","byte rec","nmail"]

        self.Y21value=["LIN1_VmSize","LIN1_VmData","LIN1_RSS","LIN1_byte_letti_I_O"]
        self.Y22value=["LIN2_VmSize","LIN2_VmData","LIN2_RSS","LIN2_byte_letti__sec","LIN2_byte_scritti__sec"]
        self.Y23value=["LIN4_VmSize","LIN4_VmData","LIN4RSS","LIN4_byte_letti__sec"]

        self.Y31value=["Allocated Heap"]
        self.Y32value=["allocated heap"]
        self.IndexY=0
        self.Xvalue=["observation","TIME","T"]
        self.IndexI=0
        self.spreed_sheet=["EXP1","EXP2","OSS1","OSS2","OSS3","VM1","VM2","VM3"]
        self.IndexZ=0
        self.i1=0
        self.i2=0
        self.istato=0

    def aggiungi_percorso_file(self, percorso):
        self.percorsi_file.append(percorso)

    def ConvertiFormatoCSV(self):
      for file_path in self.percorsi_file:
           # print(f"file_path '{file_path}'")
            df = pd.read_csv(file_path)
            # Specifica il percorso del tuo file CSV di input e di output
            # Apri il file di input in modalità lettura
            with open(file_path, 'r', newline='', encoding='utf-8') as input_file:
                # Leggi i dati dal file CSV utilizzando il separatore ";"
                reader = csv.reader(input_file, delimiter=';')
                data = list(reader)
            # Apri il file di output in modalità scrittura
            with open(file_path, 'w', newline='', encoding='utf-8') as output_file:
                # Scrivi i dati nel nuovo file CSV utilizzando il separatore ","
                writer = csv.writer(output_file, delimiter=',')
                writer.writerows(data)

    def CalcolaExp(self):
                    x_column = self.Xvalue[self.IndexI]
                    for self.i1, pathCsv in enumerate(self.percorsi_file[:2]):
                        print(pathCsv)
                        df = pd.read_csv(pathCsv)
                        spreed_sheet =  self.spreed_sheet[self.IndexZ]
                        if self.istato ==0:
                              self.Y11value
                              Y_value = list(self.Y11value)
                        else:
                               Y_value = list(self.Y12value)

                        for self.i2, y_column in enumerate(Y_value):
                          x = np.array(df[x_column])
                          y = np.array(df[y_column])
                          #calcolo slope
                          self.CalcolaSlope(x,y,y_column)

                        self.istato=self.istato+1
                        self.IndexZ=self.IndexZ+1
                    self.istato=0
    def CalcolaOss(self):
              self.IndexI=1
              indice_iniziale = len(self.percorsi_file) // 3
              indice_finale = indice_iniziale + 3  # Gli elementi centrali sono 3, 4 e 5
              x_column = self.Xvalue[self.IndexI]
              for indice in range(indice_iniziale, indice_finale):
                      pathCsv = self.percorsi_file[indice]
                      print(pathCsv)
                      df = pd.read_csv(pathCsv)
                      spreed_sheet =  self.spreed_sheet[self.IndexZ]
                      if self.istato ==0:
                              Y_value = list(self.Y21value)
                      elif self.istato ==1:
                               Y_value = list(self.Y22value)
                      elif self.istato ==2:
                               Y_value = list(self.Y23value)

                      for self.i2, y_column in enumerate(Y_value):
                          x = np.array(df[x_column])
                          y = np.array(df[y_column])
                          #calcolo slope
                          self.CalcolaSlope(x,y,y_column)
                      self.istato=self.istato+1
              self.IndexZ=self.IndexZ+1
              self.istato=0


    def CalcolaVm(self):
               self.IndexI=2
               x_column = self.Xvalue[self.IndexI]
               last_path = self.percorsi_file[-3:]
               # Itera sugli ultimi tre elementi con un ciclo for
               for pathCsv in last_path:
                    print(pathCsv)

                    df = pd.read_csv(pathCsv)
                    spreed_sheet =  self.spreed_sheet[self.IndexZ]
                    if self.istato ==0:
                              Y_value = list(self.Y31value)
                    elif self.istato >=1:
                               Y_value = list(self.Y32value)

                    for self.i2, y_column in enumerate(Y_value):
                          x = np.array(df[x_column])
                          y = np.array(df[y_column])
                          #calcolo slope
                          self.CalcolaSlope(x,y,y_column)
                    self.istato=self.istato+1
               self.IndexZ=self.IndexZ+1
               self.istato=0

    def CalcolaSlope(self,x,y,y_column):
          res = theilslopes (y,x, 0.95)
          slope, intercept, low, up = theilslopes (y,x, 0.95)
          print("Y_column: ", y_column)
          print("Slope: ", slope)
          print("Intercept: ", intercept)
          if self.IndexI==2 :
              self.slope.append(slope)
              self.intecept.append(intercept)
          #lsq_res = stats.linregress(x, y)
          fig = plt.figure()
          ax = fig.add_subplot(111)
          ax.plot(x, y, 'b.')
          ax.plot(x, res[1] + res[0] * x, 'r-')
          ax.plot(x, res[1] + res[2] * x, 'y--')
          ax.plot(x, res[1] + res[3] * x, 'y--')

          plt.show()





    def Calcola_x(self):
                i=1
                secondi_in_un_anno = 31536000  # 60 secondi * 60 minuti * 24 ore * 365 giorni
                y_memoria = 1000000000  # Sostituisci con il valore specifico di y che hai in questo caso 1GB
                for m_slope, q_intercetta in zip(self.slope,self.intecept):
                # Calcola x nell'equazione y = mx + q

                    x = (y_memoria - q_intercetta) /  m_slope
                    # Converte x in anni
                    anni = x / secondi_in_un_anno
                    # Converte x in anni
                    print(f"Nel file{i} il valore {x} secondi convertito in anni: {round(anni, 1)} anni")
                    i=i+1

# %%
# Programma principale
if __name__ == "__main__":
    CsvFile = FileCsv()
    # Ottieni un elenco di tutti i file nella cartella
    elenco_file = os.listdir(Oss_path)
    #ordino file csv nella cartella
    elenco_file_ordinato = sorted(elenco_file)
    # Itera attraverso i file nella cartella
    for nome_file in elenco_file_ordinato:
        # Crea il percorso completo del file
        percorso_completo = os.path.join(Oss_path, nome_file)
        CsvFile.aggiungi_percorso_file(percorso_completo)
        #print(percorso_completo)

    #1)Conversione nel formato csv con separatore ;
    #CsvFile.ConvertiFormatoCSV()

    #2)Analisi Gruppo EXP
    #CsvFile.CalcolaExp()


    #3)Analisi Gruppo Oss
    #CsvFile.CalcolaOss()

    #4)Analisi Gruppo Vm
    CsvFile.CalcolaVm()

    #4.1) Calcolo
    CsvFile.Calcola_x()
# Out:
# /content/Regressione/f_Vm1Regr.csv
# Y_column:  Allocated Heap
# Slope:  0.6911224682945296
# Intercept:  6562275.461669506
# /content/Regressione/g_Vm2Regr.csv
# Y_column:  allocated heap
# Slope:  0.6709499304572171
# Intercept:  5780180.563324536
# /content/Regressione/h_Vm3Regr.csv
# Y_column:  allocated heap
# Slope:  2.9030932760062105
# Intercept:  6041585.556431387
# Nel file1 il valore 1437426462.1866782 secondi convertito in anni: 45.6 anni
# Nel file2 il valore 1481809259.2381177 secondi convertito in anni: 47.0 anni
# Nel file3 il valore 342379083.25527817 secondi convertito in anni: 10.9 anni

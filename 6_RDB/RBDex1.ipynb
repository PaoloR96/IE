# %% [markdown]
# Find the R(t) and MMTF for the system whose reliability diagram is given below. In calculating. MTTF, assume all components are identical and fail randomly with failure rate λ.

# %% [markdown]
# ![1.jpg.png](data:image/png;base64,...).

# %% [markdown]
# Notiamo subito che esiste un parallelo tra C1 e C2, ed una serie tra C5 e C6;
# risolviamo subito queste due cose, ricordando le formule della serie e parallelo:

# %% [markdown]
#  ![2.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# Siccome la traccia ci dice che i failure rate sono uguali, allora saranno uguali anche le reliability dei blocchi, che assumerò pari ad R; otterremo quindi la seguente configurazione:

# %% [markdown]
# ![3.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# Pertanto:
#
#
#
# *   ${C1}//{C2} = \left[1 - (1 - R_{C1})(1 - R_{C2})\right] = 1 - (1 - R - R + R^2) = -R^2 + 2R $
#
#
# *   $ C5 \cdot C6 = R_{C5} \cdot R_{C6} = R^2 $

# %% [markdown]
# A questo punto, ci troviamo davanti un sistema non-serie-parallelo, in cui non
# è possibile trovare degli elementi in serie o in parallelo; bisogna quindi usare la **tecnica del conditioning**; per la risoluzione dell’esercizio si deve procedere in questo modo:
#
#
#
#
# 1.   Si sceglie un componente del sistema;
# 2.   Si realizzano a partire dalll’RBD iniziale due RBD differenti: uno in    cui il componete scelto è sempre attivo, mentre nell’altro sistema il componente scelto non `e funzionante;
# 3.    Si calcola la reliability dei sistemi ottenuti;
# 4. Se uno dei due RBD ottenuti al passo 2 è un Non-Serie-ParallelSystem il
# procedimento deve essere reiterato. Se invece entrambi i sistemi non sono
# Non-Series-Parallel-System la reliability del RBD di partenza è calcolata
# tramite l' applicazione del teorema della probabilità totale:
#    $ R_{\text{sys}} = R_{\text{comp}} \cdot P(\text{system work} / \text{comp work}) + (1 - R_{\text{sys}}) \cdot P(\text{system work} / \text{comp not work}) $

# %% [markdown]
# Si è scelto quindi di scegliere il **componente C4**; ora, se consideriamo che il componente **C4 non funziona**, il diagramma risultante `e il seguente:

# %% [markdown]
# ![4.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ed otteniamo la seguente equazione:
#
# $ P(\text{sys works} / \text{C4 not work}) = R_{C3} \cdot R_{C5} \cdot R_{C6} = R^3 $

# %% [markdown]
# Per quanto riguarda il caso in cui **C4 funziona**, otteniamo il seguente diagramma:

# %% [markdown]
# ![6.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# In questa configurazione, possiamo anche non considerare C5*C6, poichè non dipende da C4; possiamo quindi considerare il diagramma come un semplice parallelo tra C1//C2 e C3. L’equazione risultante è la seguente:
#
#
# ![7.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# La reliability totale del sistema risulta quindi essere:
#
# $ R_{\text{sys}} = R(R^3 - 3R^2 + 3R) + (1 - R)R^3 = -2R^3 + 3R^2 $

# %% [markdown]
# Supponendo una distribuzione esponenziale con tasso di fallimento lambda si ha che:
#
#
# $ R_{\text{sys}} = 3e^{-2\lambda t} - 2e^{-3\lambda t} $

# %% [markdown]
# Pertanto il MTTF:
#
# $ MTTF = \frac{3}{2\lambda} - \frac{2}{3\lambda} = \frac{5}{6\lambda} $
